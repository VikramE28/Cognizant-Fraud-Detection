# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("Train-1542865627584.csv")

# %%
pd.set_option("display.max_column",999)

# %%
test_ben = pd.read_csv("Test_Beneficiarydata-1542969243754.csv")

# %%
test = pd.read_csv("Test-1542969243754.csv")

# %%
test_in = pd.read_csv("Test_Inpatientdata-1542969243754.csv")

# %%
test_out = pd.read_csv("Test_Outpatientdata-1542969243754.csv")

# %%
train_ben = pd.read_csv("Train_Beneficiarydata-1542865627584.csv")

# %%
train_in = pd.read_csv("Train_Inpatientdata-1542865627584.csv")

# %%
train_out = pd.read_csv("Train_Outpatientdata-1542865627584.csv")

# %%
train_ben.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
# ...

# %%
train_ben['RenalDiseaseIndicator'].unique()
# Out:
# array(['0', 'Y'], dtype=object)

# %%
test_ben['RenalDiseaseIndicator'].unique()
# Out:
# array(['0', 'Y'], dtype=object)

# %%
train_ben['RenalDiseaseIndicator'] = train_ben['RenalDiseaseIndicator'].replace('Y',1)

# %%
test_ben['RenalDiseaseIndicator'] = test_ben['RenalDiseaseIndicator'].replace('Y',1)

# %%
train_ben['RenalDiseaseIndicator'] = train_ben['RenalDiseaseIndicator'].replace('0',0)

# %%
test_ben['RenalDiseaseIndicator'] = test_ben['RenalDiseaseIndicator'].replace('0',0)

# %%
train_ben = train_ben.drop(columns=['NoOfMonths_PartACov','NoOfMonths_PartBCov'],axis=1)

# %%
test_ben = test_ben.drop(columns=['NoOfMonths_PartACov','NoOfMonths_PartBCov'],axis=1)

# %%
train_ben
# Out:
#             BeneID         DOB  DOD  Gender  Race  RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                      0
# 1        BENE11002  1936-09-01  NaN       2     1                      0
# 2        BENE11003  1936-08-01  NaN       1     1                      0
# 3        BENE11004  1922-07-01  NaN       1     1                      0
# 4        BENE11005  1935-09-01  NaN       1     1                      0
# ...            ...         ...  ...     ...   ...                    ...
# 138551  BENE159194  1939-07-01  NaN       1     1                      0
# 138552  BENE159195  1938-12-01  NaN       2     1                      0
# 138553  BENE159196  1916-06-01  NaN       2     1                      0
# 138554  BENE159197  1930-01-01  NaN       1     1                      0
# 138555  BENE159198  1952-04-01  NaN       2     1                      0
#
#         State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# ...

# %%
test_ben
# Out:
#            BeneID         DOB         DOD  Gender  Race  \
# 0       BENE11001  1943-01-01         NaN       1     1
# 1       BENE11007  1940-09-01  2009-12-01       1     2
# 2       BENE11010  1936-07-01         NaN       2     1
# 3       BENE11011  1914-03-01         NaN       2     2
# 4       BENE11014  1938-04-01         NaN       2     1
# ...           ...         ...         ...     ...   ...
# 63963  BENE159187  1959-07-01         NaN       1     1
# 63964  BENE159193  1936-12-01         NaN       2     1
# 63965  BENE159194  1939-07-01         NaN       1     1
# 63966  BENE159196  1916-06-01         NaN       2     1
# 63967  BENE159197  1930-01-01         NaN       1     1
#
#        RenalDiseaseIndicator  State  County  ChronicCond_Alzheimer  \
# 0                          0     39     230                      1
# 1                          0     45     610                      1
# 2                          0     41      30                      2
# ...

# %%
for i in train_ben.columns:
    if "ChronicCond" in i:
        train_ben[i] = train_ben[i].replace(2,0)

# %%
for i in test_ben.columns:
    if "ChronicCond" in i:
        test_ben[i] = test_ben[i].replace(2,0)

# %%
# Cancer and Stroke data are imbalanced
train_ben['ChronicCond_Alzheimer'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# Cancer and Stroke data are imbalanced
test_ben['ChronicCond_Alzheimer'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
train_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-09-09                  5789             1068.0
# 1            NaN  2008-12-25                  5939             1068.0
# ...

# %%
train_in.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
test_in.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6'],
#       dtype='object')

# %%
train_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0      PHY347633              V5832              V5861               2724
# ...

# %%
train_ben.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race  RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                      0     39
# 1  BENE11002  1936-09-01  NaN       2     1                      0     39
# 2  BENE11003  1936-08-01  NaN       1     1                      0     52
# 3  BENE11004  1922-07-01  NaN       1     1                      0     39
# 4  BENE11005  1935-09-01  NaN       1     1                      0     24
#
#    County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     230                      1                         0
# 1     280                      0                         0
# 2     590                      1                         0
# 3     270                      1                         1
# 4     680                      0                         0
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                          1                   0                           0
# ...

# %%
test_ben.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                      0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                      0
# 2  BENE11010  1936-07-01         NaN       2     1                      0
# 3  BENE11011  1914-03-01         NaN       2     2                      0
# 4  BENE11014  1938-04-01         NaN       2     1                      1
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     45     610                      1                         1
# 2     41      30                      0                         1
# 3      1     360                      0                         1
# 4     45     780                      0                         1
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
train_ben['DOD'].isna().sum()
# Out:
# 137135

# %%
test_ben['DOD'].isna().sum()
# Out:
# 63394

# %%
train_ben.loc[train_ben.DOD.isna(),'IsDead'] = 0
train_ben.loc[train_ben.DOD.notna(),'IsDead'] = 1

# %%
test_ben.loc[test_ben.DOD.isna(),'IsDead'] = 0
test_ben.loc[test_ben.DOD.notna(),'IsDead'] = 1

# %%
train_ben['DOD'] = train_ben['DOD'].fillna('2009-12-01')

# %%
test_ben['DOD'] = test_ben['DOD'].fillna('2009-12-01')

# %%
train_ben.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01  2009-12-01       1     1                      0
# 1  BENE11002  1936-09-01  2009-12-01       2     1                      0
# 2  BENE11003  1936-08-01  2009-12-01       1     1                      0
# 3  BENE11004  1922-07-01  2009-12-01       1     1                      0
# 4  BENE11005  1935-09-01  2009-12-01       1     1                      0
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     39     280                      0                         0
# 2     52     590                      1                         0
# 3     39     270                      1                         1
# 4     24     680                      0                         0
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01  2009-12-01       1     1                      0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                      0
# 2  BENE11010  1936-07-01  2009-12-01       2     1                      0
# 3  BENE11011  1914-03-01  2009-12-01       2     2                      0
# 4  BENE11014  1938-04-01  2009-12-01       2     1                      1
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     45     610                      1                         1
# 2     41      30                      0                         1
# 3      1     360                      0                         1
# 4     45     780                      0                         1
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
train_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-09-09                  5789             1068.0
# 1            NaN  2008-12-25                  5939             1068.0
# ...

# %%
train_in['ClaimStartDt'] = pd.to_datetime(train_in['ClaimStartDt'])

# %%
test_in['ClaimStartDt'] = pd.to_datetime(test_in['ClaimStartDt'])

# %%
train_in['ClaimEndDt'] = pd.to_datetime(train_in['ClaimEndDt'])

# %%
test_in['ClaimEndDt'] = pd.to_datetime(test_in['ClaimEndDt'])

# %%
train_in['ClaimSettlementDelay'] = train_in['ClaimEndDt'] - train_in['ClaimStartDt']

# %%
test_in['ClaimSettlementDelay'] = test_in['ClaimEndDt'] - test_in['ClaimStartDt']

# %%
train_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31 2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17 2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14 2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13 2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09 2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25 2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09 2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23 2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20 2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-09-09                  5789             1068.0
# 1            NaN  2008-12-25                  5939             1068.0
# ...

# %%
train_in['ClaimSettlementDelay'] = ((train_in['ClaimEndDt'] - train_in['ClaimStartDt']).dt.days) + 1

# %%
test_in['ClaimSettlementDelay'] = ((test_in['ClaimEndDt'] - test_in['ClaimStartDt']).dt.days) + 1

# %%
train_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31 2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17 2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14 2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13 2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09 2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25 2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09 2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23 2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20 2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-09-09                  5789             1068.0
# 1            NaN  2008-12-25                  5939             1068.0
# ...

# %%
train_in=train_in.drop(columns=['ClaimStartDt', 'ClaimEndDt'],axis=1)

# %%
test_in=test_in.drop(columns=['ClaimStartDt', 'ClaimEndDt'],axis=1)

# %%
train_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11014  CLM67387  PRV57070                    9000          PHY317786
# 1  BENE11017  CLM31237  PRV54750                   14000          PHY314656
# 2  BENE11026  CLM78930  PRV53758                    2000          PHY349495
# 3  BENE11031  CLM56810  PRV55825                   16000          PHY429538
# 4  BENE11085  CLM34625  PRV52338                   19000          PHY397161
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0          PHY427017            NaN  2009-09-09                  5789
# 1          PHY426644            NaN  2008-12-25                  5939
# 2                NaN            NaN  2009-12-09                  4019
# 3          PHY371893            NaN  2009-06-23                  8208
# 4                NaN            NaN  2009-01-20                  4279
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
train_in = train_in.drop(columns=['ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6'],axis=1)

# %%
test_in = test_in.drop(columns=['ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6'],axis=1)

# %%
train_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11014  CLM67387  PRV57070                    9000          PHY317786
# 1  BENE11017  CLM31237  PRV54750                   14000          PHY314656
# 2  BENE11026  CLM78930  PRV53758                    2000          PHY349495
# 3  BENE11031  CLM56810  PRV55825                   16000          PHY429538
# 4  BENE11085  CLM34625  PRV52338                   19000          PHY397161
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0          PHY427017            NaN  2009-09-09                  5789
# 1          PHY426644            NaN  2008-12-25                  5939
# 2                NaN            NaN  2009-12-09                  4019
# 3          PHY371893            NaN  2009-06-23                  8208
# 4                NaN            NaN  2009-01-20                  4279
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
train_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0      PHY347633              V5832              V5861               2724
# ...

# %%
train_out['ClmProcedureCode_4'].unique() # 6 5 4
# Out:
# array([  nan, 7840.,  311.])

# %%
test_out['ClmProcedureCode_4'].unique() # 6 5 4
# Out:
# array([nan])

# %%
train_out = train_out.drop(columns=['ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6'],axis=1)

# %%
test_out = test_out.drop(columns=['ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6'],axis=1)

# %%
train_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0      PHY347633              V5832              V5861               2724
# ...

# %%
train_out['ClaimStartDt'] = pd.to_datetime(train_out['ClaimStartDt'])

# %%
test_out['ClaimStartDt'] = pd.to_datetime(test_out['ClaimStartDt'])

# %%
test_out = test_out.drop(columns=['ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25984\1697350293.py in <module>
# ----> 1 test_out = test_out.drop(columns=['ClmProcedureCode_4','ClmProcedureCode_5','ClmProcedureCode_6'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
train_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# ...

# %%
train_out['ClaimEndDt'] = pd.to_datetime(train_out['ClaimEndDt'])

# %%
test_out['ClaimEndDt'] = pd.to_datetime(test_out['ClaimEndDt'])

# %%
train_out['ClaimSettlementDelay'] = ((train_out['ClaimEndDt'] - train_out['ClaimStartDt']).dt.days) + 1

# %%
test_out['ClaimSettlementDelay'] = ((test_out['ClaimEndDt'] - test_out['ClaimStartDt']).dt.days) + 1

# %%
train_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11 2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12 2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27 2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06 2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22 2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# 1            NaN               6115                NaN                NaN
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02 2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23 2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07 2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29 2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12 2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0      PHY347633              V5832              V5861               2724
# 1      PHY381777               9594              E9174               4019
# ...

# %%
train_out['ClaimSettlementDelay'].value_counts()
# Out:
# 1     453348
# 21     24312
# 2      11960
# 3       4366
# 15      2735
# 4       2597
# 8       2564
# 5       2238
# 6       1511
# 10      1378
# 7       1306
# 9       1189
# 17      1136
# 11       982
# 16       975
# 12       953
# 14       947
# 13       903
# 18       808
# 19       800
# 20       727
# 24         1
# 22         1
# Name: ClaimSettlementDelay, dtype: int64

# %%
test_out['ClaimSettlementDelay'].value_counts()
# Out:
# 1     110244
# 21      5857
# 2       2853
# 3       1086
# 15       698
# 8        657
# 4        642
# 5        554
# 6        350
# 7        336
# 10       317
# 9        286
# 17       271
# 11       252
# 16       247
# 19       215
# 14       214
# 12       205
# 13       203
# 18       182
# 20       170
# 24         2
# Name: ClaimSettlementDelay, dtype: int64

# %%
train_out=train_out.drop(columns=['ClaimStartDt', 'ClaimEndDt'],axis=1)

# %%
test_out=test_out.drop(columns=['ClaimStartDt', 'ClaimEndDt'],axis=1)

# %%
train_out.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11002  CLM624349  PRV56011                      30          PHY326117
# 1  BENE11003  CLM189947  PRV57610                      80          PHY362868
# 2  BENE11003  CLM438021  PRV57595                      10          PHY328821
# 3  BENE11004  CLM121801  PRV56011                      40          PHY334319
# 4  BENE11004  CLM150998  PRV56011                     200          PHY403831
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN            NaN              78943              V5866
# 1                NaN            NaN               6115                NaN
# 2                NaN            NaN               2723                NaN
# 3                NaN            NaN              71988                NaN
# 4                NaN            NaN              82382              30000
#
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM392397  PRV55962                      30          PHY347633
# 1  BENE11001  CLM430760  PRV56112                      30          PHY381777
# 2  BENE11007  CLM233081  PRV56979                     200          PHY425311
# 3  BENE11007  CLM496381  PRV56573                      10          PHY393253
# 4  BENE11007  CLM521391  PRV56573                      10          PHY417685
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN      PHY347633              V5832              V5861
# 1                NaN      PHY381777               9594              E9174
# 2                NaN      PHY425311               7248                NaN
# 3          PHY347995            NaN              58889               2449
# 4                NaN      PHY382041               V666                NaN
#
# ...

# %%
for i in train_out.columns:
    l = len(train_out[i])
    print(i,":",(train_out[i].isna().sum()/l)*100)
# Out:
# BeneID : 0.0
# ClaimID : 0.0
# Provider : 0.0
# InscClaimAmtReimbursed : 0.0
# AttendingPhysician : 0.26963496910593604
# OperatingPhysician : 82.4974842439308
# OtherPhysician : 62.32720473908567
# ClmDiagnosisCode_1 : 2.018978747897098
# ClmDiagnosisCode_2 : 37.73730677931073
# ClmDiagnosisCode_3 : 60.741264387130926
# ClmDiagnosisCode_4 : 75.74135130384731
# ClmDiagnosisCode_5 : 85.6405858572982
# ClmDiagnosisCode_6 : 90.58286350019411
# ClmDiagnosisCode_7 : 93.63364024591635
# ClmDiagnosisCode_8 : 95.57458709731003
# ClmDiagnosisCode_9 : 97.13406613782674
# ClmDiagnosisCode_10 : 99.79082043585836
# ClmProcedureCode_1 : 99.96870998209516
# ClmProcedureCode_2 : 99.99304666268782
# ClmProcedureCode_3 : 99.9992274069653
# DeductibleAmtPaid : 0.0
# ClmAdmitDiagnosisCode : 79.63734482951769
# ClaimSettlementDelay : 0.0

# %%
for i in test_out.columns:
    l = len(test_out[i])
    print(i,":",(test_out[i].isna().sum()/l)*100)
# Out:
# BeneID : 0.0
# ClaimID : 0.0
# Provider : 0.0
# InscClaimAmtReimbursed : 0.0
# AttendingPhysician : 0.25111052836515924
# OperatingPhysician : 82.83230425695918
# OtherPhysician : 62.15939161322621
# ClmDiagnosisCode_1 : 2.0486169054600647
# ClmDiagnosisCode_2 : 37.92960958670068
# ClmDiagnosisCode_3 : 60.85059718215844
# ClmDiagnosisCode_4 : 75.78690569846076
# ClmDiagnosisCode_5 : 85.72325394744162
# ClmDiagnosisCode_6 : 90.61831994342067
# ClmDiagnosisCode_7 : 93.66661104091672
# ClmDiagnosisCode_8 : 95.60477110003895
# ClmDiagnosisCode_9 : 97.16864932732575
# ClmDiagnosisCode_10 : 99.79100611088596
# ClmProcedureCode_1 : 99.97298177859362
# ClmProcedureCode_2 : 99.99284811786302
# ClmProcedureCode_3 : 99.99841069285846
# DeductibleAmtPaid : 0.0
# ClmAdmitDiagnosisCode : 79.49396460612996
# ClaimSettlementDelay : 0.0

# %%
train_out.shape
# Out:
# (517737, 23)

# %%
test_out.shape
# Out:
# (125841, 23)

# %%
for i in train_in.columns:
    l = len(train_in[i])
    print(i,":",(train_in[i].isna().sum()/l)*100)
# Out:
# BeneID : 0.0
# ClaimID : 0.0
# Provider : 0.0
# InscClaimAmtReimbursed : 0.0
# AttendingPhysician : 0.2767208578346593
# OperatingPhysician : 41.122696051786335
# OtherPhysician : 88.41231407817364
# AdmissionDt : 0.0
# ClmAdmitDiagnosisCode : 0.0
# DeductibleAmtPaid : 2.2211790285121316
# DischargeDt : 0.0
# DiagnosisGroupCode : 0.0
# ClmDiagnosisCode_1 : 0.0
# ClmDiagnosisCode_2 : 0.5583831595592231
# ClmDiagnosisCode_3 : 1.6702080347877652
# ClmDiagnosisCode_4 : 3.7900874635568513
# ClmDiagnosisCode_5 : 7.150269308691999
# ClmDiagnosisCode_6 : 11.9533527696793
# ClmDiagnosisCode_7 : 17.932499876463904
# ClmDiagnosisCode_8 : 24.563917576715916
# ClmDiagnosisCode_9 : 33.347334091021395
# ClmDiagnosisCode_10 : 90.29747492217226
# ClmProcedureCode_1 : 42.80772841824381
# ClmProcedureCode_2 : 86.52468251223007
# ClmProcedureCode_3 : 97.61575332312101
# ClaimSettlementDelay : 0.0

# %%
for i in test_in.columns:
    l = len(test_in[i])
    print(i,":",(test_in[i].isna().sum()/l)*100)
# Out:
# BeneID : 0.0
# ClaimID : 0.0
# Provider : 0.0
# InscClaimAmtReimbursed : 0.0
# AttendingPhysician : 0.324573343105434
# OperatingPhysician : 41.482567270442885
# OtherPhysician : 89.39378075594179
# AdmissionDt : 0.0
# ClmAdmitDiagnosisCode : 0.0
# DeductibleAmtPaid : 2.0521411370537117
# DischargeDt : 0.0
# DiagnosisGroupCode : 0.0
# ClmDiagnosisCode_1 : 0.0
# ClmDiagnosisCode_2 : 0.5653858234739818
# ClmDiagnosisCode_3 : 1.7694482253167207
# ClmDiagnosisCode_4 : 4.229923568212753
# ClmDiagnosisCode_5 : 7.528007538477646
# ClmDiagnosisCode_6 : 12.532719087006598
# ClmDiagnosisCode_7 : 18.176107213904302
# ClmDiagnosisCode_8 : 24.709454507381427
# ClmDiagnosisCode_9 : 33.90220919275468
# ClmDiagnosisCode_10 : 90.71301434404775
# ClmProcedureCode_1 : 43.11590409381217
# ClmProcedureCode_2 : 86.8704847659931
# ClmProcedureCode_3 : 97.6651659512093
# ClaimSettlementDelay : 0.0

# %%
for i in train_out['ClaimID']:
    if i in train_in['ClaimID']:
        print(i)
else:
    print("Found nothing")
# Out:
# Found nothing

# %%
for i in test_out['ClaimID']:
    if i in test_in['ClaimID']:
        print(i)
else:
    print("Found nothing")
# Out:
# Found nothing

# %%
for i in train_out['BeneID']:
    if i in train_in['BeneID']:
        print(i)
else:
    print("Found nothing")
# Out:
# Found nothing

# %%
for i in test_out['BeneID']:
    if i in test_in['BeneID']:
        print(i)
else:
    print("Found nothing")
# Out:
# Found nothing

# %%
517737*0.1
# Out:
# 51773.700000000004

# %%
train_ben.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01  2009-12-01       1     1                      0
# 1  BENE11002  1936-09-01  2009-12-01       2     1                      0
# 2  BENE11003  1936-08-01  2009-12-01       1     1                      0
# 3  BENE11004  1922-07-01  2009-12-01       1     1                      0
# 4  BENE11005  1935-09-01  2009-12-01       1     1                      0
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     39     280                      0                         0
# 2     52     590                      1                         0
# 3     39     270                      1                         1
# 4     24     680                      0                         0
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01  2009-12-01       1     1                      0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                      0
# 2  BENE11010  1936-07-01  2009-12-01       2     1                      0
# 3  BENE11011  1914-03-01  2009-12-01       2     2                      0
# 4  BENE11014  1938-04-01  2009-12-01       2     1                      1
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     45     610                      1                         1
# 2     41      30                      0                         1
# 3      1     360                      0                         1
# 4     45     780                      0                         1
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
train_ben['DOB'] = pd.to_datetime(train_ben['DOB'])

# %%
test_ben['DOB'] = pd.to_datetime(test_ben['DOB'])

# %%
train_ben['DOD'] = pd.to_datetime(train_ben['DOD'])

# %%
test_ben['DOD'] = pd.to_datetime(test_ben['DOD'])

# %%
train_ben['Age'] = ((train_ben['DOD'] - train_ben['DOB']).dt.days)//365

# %%
test_ben['Age'] = ((test_ben['DOD'] - test_ben['DOB']).dt.days)//365

# %%
train_ben.head()
# Out:
#       BeneID        DOB        DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001 1943-01-01 2009-12-01       1     1                      0
# 1  BENE11002 1936-09-01 2009-12-01       2     1                      0
# 2  BENE11003 1936-08-01 2009-12-01       1     1                      0
# 3  BENE11004 1922-07-01 2009-12-01       1     1                      0
# 4  BENE11005 1935-09-01 2009-12-01       1     1                      0
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     39     280                      0                         0
# 2     52     590                      1                         0
# 3     39     270                      1                         1
# 4     24     680                      0                         0
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID        DOB        DOD  Gender  Race  RenalDiseaseIndicator  \
# 0  BENE11001 1943-01-01 2009-12-01       1     1                      0
# 1  BENE11007 1940-09-01 2009-12-01       1     2                      0
# 2  BENE11010 1936-07-01 2009-12-01       2     1                      0
# 3  BENE11011 1914-03-01 2009-12-01       2     2                      0
# 4  BENE11014 1938-04-01 2009-12-01       2     1                      1
#
#    State  County  ChronicCond_Alzheimer  ChronicCond_Heartfailure  \
# 0     39     230                      1                         0
# 1     45     610                      1                         1
# 2     41      30                      0                         1
# 3      1     360                      0                         1
# 4     45     780                      0                         1
#
#    ChronicCond_KidneyDisease  ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# ...

# %%
train_ben = train_ben.drop(columns=['DOB','DOD'],axis=1)

# %%
test_ben = test_ben.drop(columns=['DOB','DOD'],axis=1)

# %%
train_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11002       2     1                      0     39     280
# 2  BENE11003       1     1                      0     52     590
# 3  BENE11004       1     1                      0     39     270
# 4  BENE11005       1     1                      0     24     680
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      0                         0                          0
# 2                      1                         0                          0
# 3                      1                         1                          0
# 4                      0                         0                          0
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11007       1     2                      0     45     610
# 2  BENE11010       2     1                      0     41      30
# 3  BENE11011       2     2                      0      1     360
# 4  BENE11014       2     1                      1     45     780
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      1                         1                          0
# 2                      0                         1                          0
# 3                      0                         1                          1
# 4                      0                         1                          1
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
#Adding some new features

# %%
train_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11014  CLM67387  PRV57070                    9000          PHY317786
# 1  BENE11017  CLM31237  PRV54750                   14000          PHY314656
# 2  BENE11026  CLM78930  PRV53758                    2000          PHY349495
# 3  BENE11031  CLM56810  PRV55825                   16000          PHY429538
# 4  BENE11085  CLM34625  PRV52338                   19000          PHY397161
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0          PHY427017            NaN  2009-09-09                  5789
# 1          PHY426644            NaN  2008-12-25                  5939
# 2                NaN            NaN  2009-12-09                  4019
# 3          PHY371893            NaN  2009-06-23                  8208
# 4                NaN            NaN  2009-01-20                  4279
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
train_out.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11002  CLM624349  PRV56011                      30          PHY326117
# 1  BENE11003  CLM189947  PRV57610                      80          PHY362868
# 2  BENE11003  CLM438021  PRV57595                      10          PHY328821
# 3  BENE11004  CLM121801  PRV56011                      40          PHY334319
# 4  BENE11004  CLM150998  PRV56011                     200          PHY403831
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN            NaN              78943              V5866
# 1                NaN            NaN               6115                NaN
# 2                NaN            NaN               2723                NaN
# 3                NaN            NaN              71988                NaN
# 4                NaN            NaN              82382              30000
#
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM392397  PRV55962                      30          PHY347633
# 1  BENE11001  CLM430760  PRV56112                      30          PHY381777
# 2  BENE11007  CLM233081  PRV56979                     200          PHY425311
# 3  BENE11007  CLM496381  PRV56573                      10          PHY393253
# 4  BENE11007  CLM521391  PRV56573                      10          PHY417685
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN      PHY347633              V5832              V5861
# 1                NaN      PHY381777               9594              E9174
# 2                NaN      PHY425311               7248                NaN
# 3          PHY347995            NaN              58889               2449
# 4                NaN      PHY382041               V666                NaN
#
# ...

# %%
train_in['TotalClaimAmount'] = train_in['InscClaimAmtReimbursed'] + train_in['DeductibleAmtPaid']

# %%
test_in['TotalClaimAmount'] = test_in['InscClaimAmtReimbursed'] + test_in['DeductibleAmtPaid']

# %%
train_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11014  CLM67387  PRV57070                    9000          PHY317786
# 1  BENE11017  CLM31237  PRV54750                   14000          PHY314656
# 2  BENE11026  CLM78930  PRV53758                    2000          PHY349495
# 3  BENE11031  CLM56810  PRV55825                   16000          PHY429538
# 4  BENE11085  CLM34625  PRV52338                   19000          PHY397161
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0          PHY427017            NaN  2009-09-09                  5789
# 1          PHY426644            NaN  2008-12-25                  5939
# 2                NaN            NaN  2009-12-09                  4019
# 3          PHY371893            NaN  2009-06-23                  8208
# 4                NaN            NaN  2009-01-20                  4279
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
train_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11002       2     1                      0     39     280
# 2  BENE11003       1     1                      0     52     590
# 3  BENE11004       1     1                      0     39     270
# 4  BENE11005       1     1                      0     24     680
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      0                         0                          0
# 2                      1                         0                          0
# 3                      1                         1                          0
# 4                      0                         0                          0
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11007       1     2                      0     45     610
# 2  BENE11010       2     1                      0     41      30
# 3  BENE11011       2     2                      0      1     360
# 4  BENE11014       2     1                      1     45     780
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      1                         1                          0
# 2                      0                         1                          0
# 3                      0                         1                          1
# 4                      0                         1                          1
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
train_ben['IPTotalAmount'] = train_ben['IPAnnualReimbursementAmt'] + train_ben['IPAnnualDeductibleAmt']

# %%
test_ben['IPTotalAmount'] = test_ben['IPAnnualReimbursementAmt'] + test_ben['IPAnnualDeductibleAmt']

# %%
train_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11002       2     1                      0     39     280
# 2  BENE11003       1     1                      0     52     590
# 3  BENE11004       1     1                      0     39     270
# 4  BENE11005       1     1                      0     24     680
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      0                         0                          0
# 2                      1                         0                          0
# 3                      1                         1                          0
# 4                      0                         0                          0
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11007       1     2                      0     45     610
# 2  BENE11010       2     1                      0     41      30
# 3  BENE11011       2     2                      0      1     360
# 4  BENE11014       2     1                      1     45     780
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      1                         1                          0
# 2                      0                         1                          0
# 3                      0                         1                          1
# 4                      0                         1                          1
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
train_out.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11002  CLM624349  PRV56011                      30          PHY326117
# 1  BENE11003  CLM189947  PRV57610                      80          PHY362868
# 2  BENE11003  CLM438021  PRV57595                      10          PHY328821
# 3  BENE11004  CLM121801  PRV56011                      40          PHY334319
# 4  BENE11004  CLM150998  PRV56011                     200          PHY403831
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN            NaN              78943              V5866
# 1                NaN            NaN               6115                NaN
# 2                NaN            NaN               2723                NaN
# 3                NaN            NaN              71988                NaN
# 4                NaN            NaN              82382              30000
#
# ...

# %%
test_out.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM392397  PRV55962                      30          PHY347633
# 1  BENE11001  CLM430760  PRV56112                      30          PHY381777
# 2  BENE11007  CLM233081  PRV56979                     200          PHY425311
# 3  BENE11007  CLM496381  PRV56573                      10          PHY393253
# 4  BENE11007  CLM521391  PRV56573                      10          PHY417685
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN      PHY347633              V5832              V5861
# 1                NaN      PHY381777               9594              E9174
# 2                NaN      PHY425311               7248                NaN
# 3          PHY347995            NaN              58889               2449
# 4                NaN      PHY382041               V666                NaN
#
# ...

# %%
train_ben['OPTotalAmount'] = train_ben['OPAnnualReimbursementAmt'] + train_ben['OPAnnualDeductibleAmt']

# %%
test_ben['OPTotalAmount'] = test_ben['OPAnnualReimbursementAmt'] + test_ben['OPAnnualDeductibleAmt']

# %%
train_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11002       2     1                      0     39     280
# 2  BENE11003       1     1                      0     52     590
# 3  BENE11004       1     1                      0     39     270
# 4  BENE11005       1     1                      0     24     680
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      0                         0                          0
# 2                      1                         0                          0
# 3                      1                         1                          0
# 4                      0                         0                          0
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
test_ben.head()
# Out:
#       BeneID  Gender  Race  RenalDiseaseIndicator  State  County  \
# 0  BENE11001       1     1                      0     39     230
# 1  BENE11007       1     2                      0     45     610
# 2  BENE11010       2     1                      0     41      30
# 3  BENE11011       2     2                      0      1     360
# 4  BENE11014       2     1                      1     45     780
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         0                          1
# 1                      1                         1                          0
# 2                      0                         1                          0
# 3                      0                         1                          1
# 4                      0                         1                          1
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# ...

# %%
train_in
# Out:
#            BeneID   ClaimID  Provider  InscClaimAmtReimbursed  \
# 0       BENE11001  CLM46614  PRV55912                   26000
# 1       BENE11001  CLM66048  PRV55907                    5000
# 2       BENE11001  CLM68358  PRV56046                    5000
# 3       BENE11011  CLM38412  PRV52405                    5000
# 4       BENE11014  CLM63689  PRV56614                   10000
# ...           ...       ...       ...                     ...
# 40469  BENE159167  CLM69886  PRV53671                    7000
# 40470  BENE159175  CLM74504  PRV54981                    4000
# 40471  BENE159177  CLM76485  PRV56588                    3000
# 40472  BENE159177  CLM79949  PRV56575                    5000
# 40473  BENE159188  CLM69948  PRV54765                   15000
#
#       AttendingPhysician OperatingPhysician OtherPhysician AdmissionDt  \
# 0              PHY390922                NaN            NaN  2009-04-12
# 1              PHY318495          PHY318495            NaN  2009-08-31
# ...

# %%
test_in
# Out:
#           BeneID   ClaimID  Provider  InscClaimAmtReimbursed  \
# 0      BENE11014  CLM67387  PRV57070                    9000
# 1      BENE11017  CLM31237  PRV54750                   14000
# 2      BENE11026  CLM78930  PRV53758                    2000
# 3      BENE11031  CLM56810  PRV55825                   16000
# 4      BENE11085  CLM34625  PRV52338                   19000
# ...          ...       ...       ...                     ...
# 9546  BENE159139  CLM61015  PRV55021                   23000
# 9547  BENE159143  CLM42885  PRV55017                   34000
# 9548  BENE159155  CLM67124  PRV53758                    5000
# 9549  BENE159181  CLM72016  PRV57195                    3000
# 9550  BENE159196  CLM47313  PRV51854                    2000
#
#      AttendingPhysician OperatingPhysician OtherPhysician AdmissionDt  \
# 0             PHY317786          PHY427017            NaN  2009-09-09
# 1             PHY314656          PHY426644            NaN  2008-12-25
# ...

# %%
train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
test.head()
# Out:
#    Provider
# 0  PRV51002
# 1  PRV51006
# 2  PRV51009
# 3  PRV51010
# 4  PRV51018

# %%
train_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
test_in.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11014  CLM67387  PRV57070                    9000          PHY317786
# 1  BENE11017  CLM31237  PRV54750                   14000          PHY314656
# 2  BENE11026  CLM78930  PRV53758                    2000          PHY349495
# 3  BENE11031  CLM56810  PRV55825                   16000          PHY429538
# 4  BENE11085  CLM34625  PRV52338                   19000          PHY397161
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0          PHY427017            NaN  2009-09-09                  5789
# 1          PHY426644            NaN  2008-12-25                  5939
# 2                NaN            NaN  2009-12-09                  4019
# 3          PHY371893            NaN  2009-06-23                  8208
# 4                NaN            NaN  2009-01-20                  4279
#
#    DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# ...

# %%
train_in['BeneID'] = train_in['BeneID'].str.replace("BENE","")

# %%
test_in['BeneID'] = test_in['BeneID'].str.replace("BENE","")

# %%
train_in['ClaimID'] = train_in['ClaimID'].str.replace("CLM","")

# %%
test_in['ClaimID'] = test_in['ClaimID'].str.replace("CLM","")

# %%
train_in['Provider'] = train_in['Provider'].str.replace("PRV","")

# %%
test_in['Provider'] = test_in['Provider'].str.replace("PRV","")

# %%
train_in['AttendingPhysician'] = train_in['AttendingPhysician'].str.replace("PHY","")

# %%
test_in['AttendingPhysician'] = test_in['AttendingPhysician'].str.replace("PHY","")

# %%
train_in['OperatingPhysician'] = train_in['OperatingPhysician'].str.replace("PHY","")

# %%
test_in['OperatingPhysician'] = test_in['OperatingPhysician'].str.replace("PHY","")

# %%
train_in['OtherPhysician'] = train_in['OtherPhysician'].str.replace("PHY","")

# %%
test_in['OtherPhysician'] = test_in['OtherPhysician'].str.replace("PHY","")

# %%
train['PotentialFraud'] = train['PotentialFraud'].replace("Yes",1)

# %%
train['PotentialFraud'] = train['PotentialFraud'].replace("No",0)

# %%
train.head()
# Out:
#    Provider  PotentialFraud
# 0  PRV51001               0
# 1  PRV51003               1
# 2  PRV51004               0
# 3  PRV51005               1
# 4  PRV51007               0

# %%
# for i in ['BeneID',

# %%
train_in['AdmissionDt'] = pd.to_datetime(train_in['AdmissionDt'])

# %%
test_in['AdmissionDt'] = pd.to_datetime(test_in['AdmissionDt'])

# %%
train_in['DischargeDt'] = pd.to_datetime(train_in['DischargeDt'])

# %%
test_in['DischargeDt'] = pd.to_datetime(test_in['DischargeDt'])

# %%
train_in = train_in.drop(columns=['AdmissionDt','DischargeDt'],axis=1)

# %%
test_in = test_in.drop(columns=['AdmissionDt','DischargeDt'],axis=1)

# %%
train_in['ClmAdmitDiagnosisCode'].unique()
# Out:
# array(['7866', '6186', '29590', ..., '29610', '43821', '73316'],
#       dtype=object)

# %%
test_in['ClmAdmitDiagnosisCode'].unique()
# Out:
# array(['5789', '5939', '4019', ..., '6072', '4352', '96501'], dtype=object)

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import train_test_split

# # Splitting the dataset
# X_train, X_test, y_train, y_test = train_test_split(train_in.drop('PotentialFraud', axis=1), train_in['PotentialFraud'], test_size=0.2, random_state=42)

# # Training a Random Forest Regressor
# rf = RandomForestRegressor(random_state=42)
# rf.fit(X_train, y_train)

# # Getting feature importance
# importances = rf.feature_importances_

# %%
train_in.head()
# Out:
#   BeneID ClaimID Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  11001   46614    55912                   26000             390922
# 1  11001   66048    55907                    5000             318495
# 2  11001   68358    56046                    5000             372395
# 3  11011   38412    52405                    5000             369659
# 4  11014   63689    56614                   10000             379376
#
#   OperatingPhysician OtherPhysician ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                NaN            NaN                  7866             1068.0
# 1             318495            NaN                  6186             1068.0
# 2                NaN         324689                 29590             1068.0
# 3             392961         349768                   431             1068.0
# 4             398258            NaN                 78321             1068.0
#
#   DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# ...

# %%
test_in.head()
# Out:
#   BeneID ClaimID Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  11014   67387    57070                    9000             317786
# 1  11017   31237    54750                   14000             314656
# 2  11026   78930    53758                    2000             349495
# 3  11031   56810    55825                   16000             429538
# 4  11085   34625    52338                   19000             397161
#
#   OperatingPhysician OtherPhysician ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0             427017            NaN                  5789             1068.0
# 1             426644            NaN                  5939             1068.0
# 2                NaN            NaN                  4019             1068.0
# 3             371893            NaN                  8208             1068.0
# 4                NaN            NaN                  4279             1068.0
#
#   DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# ...

# %%
train_in.isna().sum()
# Out:
# BeneID                        0
# ClaimID                       0
# Provider                      0
# InscClaimAmtReimbursed        0
# AttendingPhysician          112
# OperatingPhysician        16644
# OtherPhysician            35784
# ClmAdmitDiagnosisCode         0
# DeductibleAmtPaid           899
# DiagnosisGroupCode            0
# ClmDiagnosisCode_1            0
# ClmDiagnosisCode_2          226
# ClmDiagnosisCode_3          676
# ClmDiagnosisCode_4         1534
# ClmDiagnosisCode_5         2894
# ClmDiagnosisCode_6         4838
# ClmDiagnosisCode_7         7258
# ClmDiagnosisCode_8         9942
# ClmDiagnosisCode_9        13497
# ClmDiagnosisCode_10       36547
# ClmProcedureCode_1        17326
# ClmProcedureCode_2        35020
# ClmProcedureCode_3        39509
# ClaimSettlementDelay          0
# TotalClaimAmount            899
# dtype: int64

# %%
test_in.isna().sum()
# Out:
# BeneID                       0
# ClaimID                      0
# Provider                     0
# InscClaimAmtReimbursed       0
# AttendingPhysician          31
# OperatingPhysician        3962
# OtherPhysician            8538
# ClmAdmitDiagnosisCode        0
# DeductibleAmtPaid          196
# DiagnosisGroupCode           0
# ClmDiagnosisCode_1           0
# ClmDiagnosisCode_2          54
# ClmDiagnosisCode_3         169
# ClmDiagnosisCode_4         404
# ClmDiagnosisCode_5         719
# ClmDiagnosisCode_6        1197
# ClmDiagnosisCode_7        1736
# ClmDiagnosisCode_8        2360
# ClmDiagnosisCode_9        3238
# ClmDiagnosisCode_10       8664
# ClmProcedureCode_1        4118
# ClmProcedureCode_2        8297
# ClmProcedureCode_3        9328
# ClaimSettlementDelay         0
# TotalClaimAmount           196
# dtype: int64

# %%
train_in['TotalClaimAmount'].mean()
# Out:
# 11114.92406822489

# %%
test_in['TotalClaimAmount'].mean()
# Out:
# 11118.766435061465

# %%
train_in['TotalClaimAmount'].mode()
# Out:
# 0    5068.0
# Name: TotalClaimAmount, dtype: float64

# %%
test_in['TotalClaimAmount'].mode()
# Out:
# 0    5068.0
# Name: TotalClaimAmount, dtype: float64

# %%
cols = [col for col in train_in.columns if col in train_out.columns]

# %%
cols = [col for col in test_in.columns if col in test_out.columns]

# %%
cols
# Out:
# ['BeneID',
#  'ClaimID',
#  'Provider',
#  'InscClaimAmtReimbursed',
#  'AttendingPhysician',
#  'OperatingPhysician',
#  'OtherPhysician',
#  'ClmAdmitDiagnosisCode',
#  'DeductibleAmtPaid',
#  'ClmDiagnosisCode_1',
#  'ClmDiagnosisCode_2',
#  'ClmDiagnosisCode_3',
#  'ClmDiagnosisCode_4',
#  'ClmDiagnosisCode_5',
#  'ClmDiagnosisCode_6',
#  'ClmDiagnosisCode_7',
#  'ClmDiagnosisCode_8',
#  'ClmDiagnosisCode_9',
#  'ClmDiagnosisCode_10',
#  'ClmProcedureCode_1',
#  'ClmProcedureCode_2',
#  'ClmProcedureCode_3',
#  'ClaimSettlementDelay']

# %%
cols
# Out:
# ['BeneID',
#  'ClaimID',
#  'Provider',
#  'InscClaimAmtReimbursed',
#  'AttendingPhysician',
#  'OperatingPhysician',
#  'OtherPhysician',
#  'ClmAdmitDiagnosisCode',
#  'DeductibleAmtPaid',
#  'ClmDiagnosisCode_1',
#  'ClmDiagnosisCode_2',
#  'ClmDiagnosisCode_3',
#  'ClmDiagnosisCode_4',
#  'ClmDiagnosisCode_5',
#  'ClmDiagnosisCode_6',
#  'ClmDiagnosisCode_7',
#  'ClmDiagnosisCode_8',
#  'ClmDiagnosisCode_9',
#  'ClmDiagnosisCode_10',
#  'ClmProcedureCode_1',
#  'ClmProcedureCode_2',
#  'ClmProcedureCode_3',
#  'ClaimSettlementDelay']

# %%
Train_Allpatientdata=pd.merge(train_out,train_in,
                              left_on=['BeneID','ClaimID','Provider','InscClaimAmtReimbursed','AttendingPhysician','OperatingPhysician','OtherPhysician','ClmAdmitDiagnosisCode','DeductibleAmtPaid','ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4','ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10','ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3','ClaimSettlementDelay'],
                              right_on=['BeneID','ClaimID','Provider','InscClaimAmtReimbursed','AttendingPhysician','OperatingPhysician','OtherPhysician','ClmAdmitDiagnosisCode','DeductibleAmtPaid','ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4','ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10','ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3','ClaimSettlementDelay']
                              ,how='outer')

# %%
Test_Allpatientdata=pd.merge(test_out,test_in,
                              left_on=['BeneID','ClaimID','Provider','InscClaimAmtReimbursed','AttendingPhysician','OperatingPhysician','OtherPhysician','ClmAdmitDiagnosisCode','DeductibleAmtPaid','ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4','ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10','ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3','ClaimSettlementDelay'],
                              right_on=['BeneID','ClaimID','Provider','InscClaimAmtReimbursed','AttendingPhysician','OperatingPhysician','OtherPhysician','ClmAdmitDiagnosisCode','DeductibleAmtPaid','ClmDiagnosisCode_1','ClmDiagnosisCode_2','ClmDiagnosisCode_3','ClmDiagnosisCode_4','ClmDiagnosisCode_5','ClmDiagnosisCode_6','ClmDiagnosisCode_7','ClmDiagnosisCode_8','ClmDiagnosisCode_9','ClmDiagnosisCode_10','ClmProcedureCode_1','ClmProcedureCode_2','ClmProcedureCode_3','ClaimSettlementDelay']
                              ,how='outer')

# %%
Train_Allpatientdata.shape
# Out:
# (558211, 25)

# %%
Test_Allpatientdata.shape
# Out:
# (135392, 25)

# %%
Train_Allpatientdata.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11002  CLM624349  PRV56011                      30          PHY326117
# 1  BENE11003  CLM189947  PRV57610                      80          PHY362868
# 2  BENE11003  CLM438021  PRV57595                      10          PHY328821
# 3  BENE11004  CLM121801  PRV56011                      40          PHY334319
# 4  BENE11004  CLM150998  PRV56011                     200          PHY403831
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN            NaN              78943              V5866
# 1                NaN            NaN               6115                NaN
# 2                NaN            NaN               2723                NaN
# 3                NaN            NaN              71988                NaN
# 4                NaN            NaN              82382              30000
#
# ...

# %%
Test_Allpatientdata.head()
# Out:
#       BeneID    ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM392397  PRV55962                      30          PHY347633
# 1  BENE11001  CLM430760  PRV56112                      30          PHY381777
# 2  BENE11007  CLM233081  PRV56979                     200          PHY425311
# 3  BENE11007  CLM496381  PRV56573                      10          PHY393253
# 4  BENE11007  CLM521391  PRV56573                      10          PHY417685
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0                NaN      PHY347633              V5832              V5861
# 1                NaN      PHY381777               9594              E9174
# 2                NaN      PHY425311               7248                NaN
# 3          PHY347995            NaN              58889               2449
# 4                NaN      PHY382041               V666                NaN
#
# ...

# %%
train_all = pd.merge(Train_Allpatientdata,train_ben,left_on='BeneID',right_on='BeneID',how='inner')

# %%
test_all = pd.merge(Test_Allpatientdata,test_ben,left_on='BeneID',right_on='BeneID',how='inner')

# %%
train_all.shape
# Out:
# (517737, 49)

# %%
test_all.shape
# Out:
# (125841, 49)

# %%
train_all.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'ClaimSettlementDelay', 'DiagnosisGroupCode', 'TotalClaimAmount',
#        'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
# ...

# %%
test_all.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'ClaimSettlementDelay', 'DiagnosisGroupCode', 'TotalClaimAmount',
#        'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
# ...

# %%
train_all.dtypes
# Out:
# BeneID                              object
# ClaimID                             object
# Provider                            object
# InscClaimAmtReimbursed               int64
# AttendingPhysician                  object
# OperatingPhysician                  object
# OtherPhysician                      object
# ClmDiagnosisCode_1                  object
# ClmDiagnosisCode_2                  object
# ClmDiagnosisCode_3                  object
# ClmDiagnosisCode_4                  object
# ClmDiagnosisCode_5                  object
# ClmDiagnosisCode_6                  object
# ClmDiagnosisCode_7                  object
# ClmDiagnosisCode_8                  object
# ClmDiagnosisCode_9                  object
# ClmDiagnosisCode_10                 object
# ClmProcedureCode_1                 float64
# ClmProcedureCode_2                 float64
# ClmProcedureCode_3                 float64
# DeductibleAmtPaid                  float64
# ClmAdmitDiagnosisCode               object
# ...

# %%
test_all.dtypes
# Out:
# BeneID                              object
# ClaimID                             object
# Provider                            object
# InscClaimAmtReimbursed               int64
# AttendingPhysician                  object
# OperatingPhysician                  object
# OtherPhysician                      object
# ClmDiagnosisCode_1                  object
# ClmDiagnosisCode_2                  object
# ClmDiagnosisCode_3                  object
# ClmDiagnosisCode_4                  object
# ClmDiagnosisCode_5                  object
# ClmDiagnosisCode_6                  object
# ClmDiagnosisCode_7                  object
# ClmDiagnosisCode_8                  object
# ClmDiagnosisCode_9                  object
# ClmDiagnosisCode_10                 object
# ClmProcedureCode_1                 float64
# ClmProcedureCode_2                 float64
# ClmProcedureCode_3                 float64
# DeductibleAmtPaid                  float64
# ClmAdmitDiagnosisCode               object
# ...

# %%
train_all.isnull().sum()*100/len(train_all)
# Out:
# BeneID                               0.000000
# ClaimID                              0.000000
# Provider                             0.000000
# InscClaimAmtReimbursed               0.000000
# AttendingPhysician                   0.269635
# OperatingPhysician                  82.497484
# OtherPhysician                      62.327205
# ClmDiagnosisCode_1                   2.018979
# ClmDiagnosisCode_2                  37.737307
# ClmDiagnosisCode_3                  60.741264
# ClmDiagnosisCode_4                  75.741351
# ClmDiagnosisCode_5                  85.640586
# ClmDiagnosisCode_6                  90.582864
# ClmDiagnosisCode_7                  93.633640
# ClmDiagnosisCode_8                  95.574587
# ClmDiagnosisCode_9                  97.134066
# ClmDiagnosisCode_10                 99.790820
# ClmProcedureCode_1                  99.968710
# ClmProcedureCode_2                  99.993047
# ClmProcedureCode_3                  99.999227
# ...

# %%
test_all.isnull().sum()*100/len(test_all)
# Out:
# BeneID                               0.000000
# ClaimID                              0.000000
# Provider                             0.000000
# InscClaimAmtReimbursed               0.000000
# AttendingPhysician                   0.251111
# OperatingPhysician                  82.832304
# OtherPhysician                      62.159392
# ClmDiagnosisCode_1                   2.048617
# ClmDiagnosisCode_2                  37.929610
# ClmDiagnosisCode_3                  60.850597
# ClmDiagnosisCode_4                  75.786906
# ClmDiagnosisCode_5                  85.723254
# ClmDiagnosisCode_6                  90.618320
# ClmDiagnosisCode_7                  93.666611
# ClmDiagnosisCode_8                  95.604771
# ClmDiagnosisCode_9                  97.168649
# ClmDiagnosisCode_10                 99.791006
# ClmProcedureCode_1                  99.972982
# ClmProcedureCode_2                  99.992848
# ClmProcedureCode_3                  99.998411
# ...

# %%
train_all_f =pd.merge(train,train_all,on='Provider')

# %%
test_all_f =pd.merge(test,test_all,on='Provider')

# %%
train_all_f.head()
# Out:
#    Provider  PotentialFraud     BeneID    ClaimID  InscClaimAmtReimbursed  \
# 0  PRV51001               0  BENE11727  CLM733300                      20
# 1  PRV51001               0  BENE24646  CLM372475                     700
# 2  PRV51001               0  BENE31617  CLM748221                     900
# 3  PRV51001               0  BENE32715  CLM272936                     500
# 4  PRV51001               0  BENE49220  CLM452024                      70
#
#   AttendingPhysician OperatingPhysician OtherPhysician ClmDiagnosisCode_1  \
# 0          PHY383007                NaN      PHY383007               5953
# 1          PHY405682                NaN      PHY402512              78650
# 2          PHY345302                NaN            NaN               V446
# 3          PHY318842          PHY392882            NaN              78964
# 4          PHY402512                NaN            NaN              78965
#
# ...

# %%
test_all_f.head()
# Out:
#    Provider     BeneID    ClaimID  InscClaimAmtReimbursed AttendingPhysician  \
# 0  PRV51002  BENE13342  CLM129901                     100          PHY418314
# 1  PRV51002  BENE13915  CLM163936                      40          PHY399539
# 2  PRV51002  BENE13915  CLM348696                      70          PHY352340
# 3  PRV51002  BENE13915  CLM500906                     100          PHY366184
# 4  PRV51002  BENE14575  CLM272820                     400          PHY401762
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0          PHY418314      PHY413853                514              79092
# 1          PHY421140            NaN               7840              V4502
# 2                NaN            NaN              V4581               V173
# 3                NaN            NaN              42789                NaN
# 4                NaN      PHY330212               1532                NaN
#
# ...

# %%
train_all_f['PotentialFraud'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
train_all_f.isna().sum()
# Out:
# Provider                                0
# PotentialFraud                          0
# BeneID                                  0
# ClaimID                                 0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                   1396
# OperatingPhysician                 427120
# OtherPhysician                     322691
# ClmDiagnosisCode_1                  10453
# ClmDiagnosisCode_2                 195380
# ClmDiagnosisCode_3                 314480
# ClmDiagnosisCode_4                 392141
# ClmDiagnosisCode_5                 443393
# ClmDiagnosisCode_6                 468981
# ClmDiagnosisCode_7                 484776
# ClmDiagnosisCode_8                 494825
# ClmDiagnosisCode_9                 502899
# ClmDiagnosisCode_10                516654
# ClmProcedureCode_1                 517575
# ClmProcedureCode_2                 517701
# ClmProcedureCode_3                 517733
# DeductibleAmtPaid                       0
# ...

# %%
test_all_f.isna().sum()
# Out:
# Provider                                0
# BeneID                                  0
# ClaimID                                 0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                    316
# OperatingPhysician                 104237
# OtherPhysician                      78222
# ClmDiagnosisCode_1                   2578
# ClmDiagnosisCode_2                  47731
# ClmDiagnosisCode_3                  76575
# ClmDiagnosisCode_4                  95371
# ClmDiagnosisCode_5                 107875
# ClmDiagnosisCode_6                 114035
# ClmDiagnosisCode_7                 117871
# ClmDiagnosisCode_8                 120310
# ClmDiagnosisCode_9                 122278
# ClmDiagnosisCode_10                125578
# ClmProcedureCode_1                 125807
# ClmProcedureCode_2                 125832
# ClmProcedureCode_3                 125839
# DeductibleAmtPaid                       0
# ClmAdmitDiagnosisCode              100036
# ...

# %%
train_all_f.shape
# Out:
# (517737, 50)

# %%
test_all_f.shape
# Out:
# (125841, 49)

# %%
train_all_f['TotalClaimAmount'] = train_all_f['InscClaimAmtReimbursed'] + train_all_f['DeductibleAmtPaid']

# %%
test_all_f['TotalClaimAmount'] = test_all_f['InscClaimAmtReimbursed'] + test_all_f['DeductibleAmtPaid']

# %%
train_in.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClaimSettlementDelay', 'TotalClaimAmount'],
#       dtype='object')

# %%
test_in.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClaimSettlementDelay', 'TotalClaimAmount'],
#       dtype='object')

# %%
train_out.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'ClaimSettlementDelay'],
#       dtype='object')

# %%
test_out.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'DeductibleAmtPaid', 'ClmAdmitDiagnosisCode',
#        'ClaimSettlementDelay'],
#       dtype='object')

# %%
count_classes = pd.value_counts(train_all_f['PotentialFraud'], sort = True)
print("Percent Distribution of Potential Fraud class:- \n",count_classes*100/len(train_all_f))
LABELS = ["Non Fraud", "Fraud"]
#Drawing a barplot
count_classes.plot(kind = 'bar', rot=0,figsize=(10,6))

#Giving titles and labels to the plot
plt.title("Potential Fraud distribution in Aggregated claim transactional data")
plt.xticks(range(2), LABELS)
plt.xlabel("Potential Fraud Class ")
plt.ylabel("Number of PotentialFraud per Class ")
# Out:
# Percent Distribution of Potential Fraud class:-
#  0    63.418879
# 1    36.581121
# Name: PotentialFraud, dtype: float64
# Text(0, 0.5, 'Number of PotentialFraud per Class ')

# %%
train_all_f.shape
# Out:
# (517737, 50)

# %%
test_all_f.shape
# Out:
# (125841, 49)

# %%
train_all_f.isnull().sum()*100/len(train_all_f)
# Out:
# Provider                             0.000000
# PotentialFraud                       0.000000
# BeneID                               0.000000
# ClaimID                              0.000000
# InscClaimAmtReimbursed               0.000000
# AttendingPhysician                   0.269635
# OperatingPhysician                  82.497484
# OtherPhysician                      62.327205
# ClmDiagnosisCode_1                   2.018979
# ClmDiagnosisCode_2                  37.737307
# ClmDiagnosisCode_3                  60.741264
# ClmDiagnosisCode_4                  75.741351
# ClmDiagnosisCode_5                  85.640586
# ClmDiagnosisCode_6                  90.582864
# ClmDiagnosisCode_7                  93.633640
# ClmDiagnosisCode_8                  95.574587
# ClmDiagnosisCode_9                  97.134066
# ClmDiagnosisCode_10                 99.790820
# ClmProcedureCode_1                  99.968710
# ClmProcedureCode_2                  99.993047
# ...

# %%
test_all_f.isnull().sum()*100/len(test_all_f)
# Out:
# Provider                             0.000000
# BeneID                               0.000000
# ClaimID                              0.000000
# InscClaimAmtReimbursed               0.000000
# AttendingPhysician                   0.251111
# OperatingPhysician                  82.832304
# OtherPhysician                      62.159392
# ClmDiagnosisCode_1                   2.048617
# ClmDiagnosisCode_2                  37.929610
# ClmDiagnosisCode_3                  60.850597
# ClmDiagnosisCode_4                  75.786906
# ClmDiagnosisCode_5                  85.723254
# ClmDiagnosisCode_6                  90.618320
# ClmDiagnosisCode_7                  93.666611
# ClmDiagnosisCode_8                  95.604771
# ClmDiagnosisCode_9                  97.168649
# ClmDiagnosisCode_10                 99.791006
# ClmProcedureCode_1                  99.972982
# ClmProcedureCode_2                  99.992848
# ClmProcedureCode_3                  99.998411
# ...

# %%
train_all_f = train_all_f.drop(columns=['DiagnosisGroupCode'],axis=1)

# %%
test_all_f = test_all_f.drop(columns=['DiagnosisGroupCode'],axis=1)

# %%
train_all_f.head()
# Out:
#    Provider  PotentialFraud     BeneID    ClaimID  InscClaimAmtReimbursed  \
# 0  PRV51001               0  BENE11727  CLM733300                      20
# 1  PRV51001               0  BENE24646  CLM372475                     700
# 2  PRV51001               0  BENE31617  CLM748221                     900
# 3  PRV51001               0  BENE32715  CLM272936                     500
# 4  PRV51001               0  BENE49220  CLM452024                      70
#
#   AttendingPhysician OperatingPhysician OtherPhysician ClmDiagnosisCode_1  \
# 0          PHY383007                NaN      PHY383007               5953
# 1          PHY405682                NaN      PHY402512              78650
# 2          PHY345302                NaN            NaN               V446
# 3          PHY318842          PHY392882            NaN              78964
# 4          PHY402512                NaN            NaN              78965
#
# ...

# %%
test_all_f.head()
# Out:
#    Provider     BeneID    ClaimID  InscClaimAmtReimbursed AttendingPhysician  \
# 0  PRV51002  BENE13342  CLM129901                     100          PHY418314
# 1  PRV51002  BENE13915  CLM163936                      40          PHY399539
# 2  PRV51002  BENE13915  CLM348696                      70          PHY352340
# 3  PRV51002  BENE13915  CLM500906                     100          PHY366184
# 4  PRV51002  BENE14575  CLM272820                     400          PHY401762
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0          PHY418314      PHY413853                514              79092
# 1          PHY421140            NaN               7840              V4502
# 2                NaN            NaN              V4581               V173
# 3                NaN            NaN              42789                NaN
# 4                NaN      PHY330212               1532                NaN
#
# ...

# %%
train_all_f.shape
# Out:
# (517737, 49)

# %%
test_all_f.shape
# Out:
# (125841, 48)

# %%
test_all_f.head()
# Out:
#    Provider     BeneID    ClaimID  InscClaimAmtReimbursed AttendingPhysician  \
# 0  PRV51002  BENE13342  CLM129901                     100          PHY418314
# 1  PRV51002  BENE13915  CLM163936                      40          PHY399539
# 2  PRV51002  BENE13915  CLM348696                      70          PHY352340
# 3  PRV51002  BENE13915  CLM500906                     100          PHY366184
# 4  PRV51002  BENE14575  CLM272820                     400          PHY401762
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0          PHY418314      PHY413853                514              79092
# 1          PHY421140            NaN               7840              V4502
# 2                NaN            NaN              V4581               V173
# 3                NaN            NaN              42789                NaN
# 4                NaN      PHY330212               1532                NaN
#
# ...

# %%
train_all_f.head()
# Out:
#    Provider  PotentialFraud     BeneID    ClaimID  InscClaimAmtReimbursed  \
# 0  PRV51001               0  BENE11727  CLM733300                      20
# 1  PRV51001               0  BENE24646  CLM372475                     700
# 2  PRV51001               0  BENE31617  CLM748221                     900
# 3  PRV51001               0  BENE32715  CLM272936                     500
# 4  PRV51001               0  BENE49220  CLM452024                      70
#
#   AttendingPhysician OperatingPhysician OtherPhysician ClmDiagnosisCode_1  \
# 0          PHY383007                NaN      PHY383007               5953
# 1          PHY405682                NaN      PHY402512              78650
# 2          PHY345302                NaN            NaN               V446
# 3          PHY318842          PHY392882            NaN              78964
# 4          PHY402512                NaN            NaN              78965
#
# ...

# %%
test_all_f_copy = test_all_f

# %%
col = train_all_f.columns

# %%
col
# Out:
# Index(['Provider', 'PotentialFraud', 'BeneID', 'ClaimID',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'DeductibleAmtPaid',
#        'ClmAdmitDiagnosisCode', 'ClaimSettlementDelay', 'TotalClaimAmount',
#        'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
# ...

# %%
test_all_f = pd.concat([test_all_f,train_all_f[col]])

# %%
test_all_f.shape
# Out:
# (643578, 49)

# %%
test_all_f.head()
# Out:
#    Provider     BeneID    ClaimID  InscClaimAmtReimbursed AttendingPhysician  \
# 0  PRV51002  BENE13342  CLM129901                     100          PHY418314
# 1  PRV51002  BENE13915  CLM163936                      40          PHY399539
# 2  PRV51002  BENE13915  CLM348696                      70          PHY352340
# 3  PRV51002  BENE13915  CLM500906                     100          PHY366184
# 4  PRV51002  BENE14575  CLM272820                     400          PHY401762
#
#   OperatingPhysician OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0          PHY418314      PHY413853                514              79092
# 1          PHY421140            NaN               7840              V4502
# 2                NaN            NaN              V4581               V173
# 3                NaN            NaN              42789                NaN
# 4                NaN      PHY330212               1532                NaN
#
# ...

# %%
train_all_f.shape
# Out:
# (517737, 49)

# %%
len(train_all_f['Provider'].unique())
# Out:
# 5012

# %%
train_all_f.head(50)
# Out:
#     Provider  PotentialFraud      BeneID    ClaimID  InscClaimAmtReimbursed  \
# 0   PRV51001               0   BENE11727  CLM733300                      20
# 1   PRV51001               0   BENE24646  CLM372475                     700
# 2   PRV51001               0   BENE31617  CLM748221                     900
# 3   PRV51001               0   BENE32715  CLM272936                     500
# 4   PRV51001               0   BENE49220  CLM452024                      70
# 5   PRV51001               0   BENE56354  CLM403535                     100
# 6   PRV51001               0   BENE57060  CLM578620                     300
# 7   PRV51001               0   BENE61975  CLM260292                      60
# 8   PRV51001               0   BENE79474  CLM180133                    1000
# 9   PRV51001               0   BENE81544  CLM352646                     100
# 10  PRV51001               0   BENE86784  CLM119495                      10
# ...

# %%
train_all_f = train_all_f.groupby(['Provider','PotentialFraud'],as_index = False).agg("sum")
test_all_f = test_all_f.groupby(['Provider'],as_index = False).agg("sum")

# %%
X = train_all_f.drop(columns = ['Provider','PotentialFraud'])
y = train_all_f['PotentialFraud']

# %%
X.shape
# Out:
# (5012, 31)

# %%
y.shape
# Out:
# (5012,)

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: PotentialFraud, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(X)


X_std=sc.transform(X)
X_tested=sc.transform(test_all_f.iloc[:,2:])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - PotentialFraud
# Feature names seen at fit time, yet now missing:
# - InscClaimAmtReimbursed
#
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_val,y_train,y_val=train_test_split(X_std,y,test_size=0.2,random_state=42,stratify=y,shuffle=True)

# %%
X_train.shape
# Out:
# (4009, 31)

# %%
y.shape
# Out:
# (5012,)

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
log = LogisticRegressionCV(cv = 10, class_weight = "balanced", random_state = 101)

# %%
log.fit(X_train, y_train)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
pred_x = log.predict_proba(X_train)

# %%
from sklearn.metrics import roc_curve, auc,precision_recall_curve
fpr, tpr, thresholds = roc_curve(y_val,log.predict_proba(X_val)[:,1])         #log_val_pred_probability[:,1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')

for label in range(1,10,1):
    plt.text((10-label)/10,(10-label)/10,thresholds[label*15],fontdict={'size': 14})

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
log_train_pred_probability=log.predict_proba(X_train)
log_val_pred_probability=log.predict_proba(X_val)

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize=(12,8))

sns.distplot(log.predict_proba(X_train)[:,1],color='darkblue')
sns.distplot(log.predict_proba(X_val)[:,1],color='firebrick')
plt.title('Predictions of Train and Validation ')
plt.xlim([0, 1])

plt.tight_layout()

plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import roc_curve, auc,precision_recall_curve
fpr, tpr, thresholds = roc_curve(y_val,log.predict_proba(X_val)[:,1])         #log_val_pred_probability[:,1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')

for label in range(1,10,1):
    plt.text((10-label)/10,(10-label)/10,thresholds[label*15],fontdict={'size': 14})

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
fpr, tpr, thresholds =roc_curve(y_val, log.predict_proba(X_val)[:,1],pos_label=1)     #log_val_pred_probability[:,1])
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)
# Out:
# Area under the ROC curve : 0.753412

# %%
precision, recall, _ = precision_recall_curve(y_val, log.predict_proba(X_val)[:,1])

plt.plot(precision,recall)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Vs Recall')
# Out:
# Text(0.5, 1.0, 'Precision Vs Recall')

# %%
fig = plt.figure(figsize=(12,8))

sns.distplot(tpr,color='firebrick')

sns.distplot(fpr,color='darkblue')
plt.title('TPR Vs FPR ')
plt.xlim([-.25, 1.2])

plt.text(0.1,4,'Negatives',color='darkblue')
plt.text(0.7,4,'Positives',color='firebrick')
plt.xlabel('Probability')
plt.ylabel('Distribution')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def validate_model(clf, x_train, x_test, y_train, y_test):
    # predict the probability of train data
    y_train_pred = pred_prob(clf, x_train)
    # predict the probability of test data
    y_test_pred = pred_prob(clf, x_test)
    # calculate tpr, fpr for diffeent thresholds using roc_curve
    train_fpr, train_tpr, tr_thresholds = roc_curve(y_train, y_train_pred)
    test_fpr, test_tpr, te_thresholds = roc_curve(y_test, y_test_pred)
    
    # calculate auc for train and test
    train_auc = auc(train_fpr, train_tpr)
    print("Train AUC = ", train_auc)
    test_auc = auc(test_fpr, test_tpr)
    print("Test AUC = ", test_auc)
    
    draw_roc(train_fpr, train_tpr, test_fpr, test_tpr)
    
    best_t = find_best_threshold(tr_thresholds, train_fpr, train_tpr)
    
#     print(len(test_prediction))
    
    return test_auc, best_t

# %%
def pred_prob(clf, data): 
    # predicts the probabability of class label using the model
    y_pred = clf.predict_proba(data)[:,1]
    return y_pred

def draw_roc(train_fpr, train_tpr, test_fpr, test_tpr):
    # calculate auc for train and test
    train_auc = auc(train_fpr, train_tpr)
    test_auc = auc(test_fpr, test_tpr)
    plt.plot(train_fpr, train_tpr, label="Train AUC ="+"{:.4f}".format(train_auc))
    plt.plot(test_fpr, test_tpr, label="Test AUC ="+"{:.4f}".format(test_auc))
    plt.legend()
    plt.xlabel("False Positive Rate(FPR)", size = 14)
    plt.ylabel("True Positive Rate(TPR)", size = 14)
    plt.title("Area Under Curve", size = 16)
    plt.grid(b=True, which='major', color='g', linestyle='-')
    plt.show()
    
def find_best_threshold(threshold, fpr, tpr):
    t = threshold[np.argmax(tpr*(1-fpr))]
#     print("max(tpr*(1-fpr)) = ", max(tpr*(1-fpr)), "for threshold = ", np.round(t,3))
    return t

def predict_with_best_t(proba, threshold):
    predictions = []
    for i in proba:
        if i>=threshold:
            predictions.append(1)
        else:
            predictions.append(0)
    return predictions

# %%
test_auc2, best_t2 = validate_model(log, X_train, X_val, y_train, y_val)

print("Best Threshold = {:.4f}".format(best_t2))
print("Model AUC is : {:.4f}".format(test_auc2))
# Out:
# Train AUC =  0.7699048595173905
# Test AUC =  0.7534123991791152
# C:\Users\hp\AppData\Local\Temp\ipykernel_25984\373669981.py:16: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='g', linestyle='-')
# Best Threshold = 0.4323
# Model AUC is : 0.7534

# %%
log_train_pred_best=(log.predict_proba(X_train)[:,1]>0.3967).astype(bool)
log_val_pred_best=(log.predict_proba(X_val)[:,1]>0.3967).astype(bool)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,cohen_kappa_score,roc_auc_score,f1_score,auc

cm0 = confusion_matrix(y_train, log_train_pred_best,labels=[1,0])
print('Confusion Matrix Train : \n', cm0)

cm1 = confusion_matrix(y_val, log_val_pred_best,labels=[1,0])
print('Confusion Matrix Val: \n', cm1)

total0=sum(sum(cm0))
total1=sum(sum(cm1))
#####from confusion matrix calculate accuracy
accuracy0=(cm0[0,0]+cm0[1,1])/total0
print ('Accuracy Train: ', accuracy0)

accuracy1=(cm1[0,0]+cm1[1,1])/total1
print ('Accuracy Val: ', accuracy1)

sensitivity0 = cm0[0,0]/(cm0[0,0]+cm0[0,1])
print('Sensitivity Train : ', sensitivity0 )

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity Val: ', sensitivity1 )


specificity0 = cm0[1,1]/(cm0[1,0]+cm0[1,1])
print('Specificity Train: ', specificity0)

specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity Val: ', specificity1)

KappaValue=cohen_kappa_score(y_val, log_val_pred_60)
print("Kappa Value :",KappaValue)
AUC=roc_auc_score(y_val, log_val_pred_60)

print("AUC         :",AUC)

print("F1-Score Train  : ",f1_score(y_train, log_train_pred_best))

print("F1-Score Val  : ",f1_score(y_val, log_val_pred_best))
# Out:
# Confusion Matrix Train :
#  [[ 370    0]
#  [3639    0]]
# Confusion Matrix Val:
#  [[ 92   0]
#  [911   0]]
# Accuracy Train:  0.09229234222998253
# Accuracy Val:  0.09172482552342971
# Sensitivity Train :  1.0
# Sensitivity Val:  1.0
# Specificity Train:  0.0
# Specificity Val:  0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25984\1782445880.py in <module>
#      29 print('Specificity Val: ', specificity1)
#      30
# ---> 31 KappaValue=cohen_kappa_score(y_val, log_val_pred_60)
#      32 print("Kappa Value :",KappaValue)
#      33 AUC=roc_auc_score(y_val, log_val_pred_60)
#
# NameError: name 'log_val_pred_60' is not defined

# %%
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.svm import SVC  
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn import metrics
from sklearn.metrics import roc_curve, auc , f1_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.calibration import CalibratedClassifierCV
import numpy as np
import seaborn as sns

# %%
param_grid={'C':[0.5, 1.0], 'gamma': [1,0.1,0.01],'kernel': ['rbf', 'poly', 'sigmoid']}

grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END .........................C=0.5, gamma=1, kernel=rbf; total time=   0.5s
# [CV] END .........................C=0.5, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=0.5, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=0.5, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=0.5, gamma=1, kernel=rbf; total time=   0.4s
# [CV] END ........................C=0.5, gamma=1, kernel=poly; total time= 2.1min
# [CV] END ........................C=0.5, gamma=1, kernel=poly; total time= 1.7min
# [CV] END ........................C=0.5, gamma=1, kernel=poly; total time= 2.6min
# [CV] END ........................C=0.5, gamma=1, kernel=poly; total time= 2.8min
# [CV] END ........................C=0.5, gamma=1, kernel=poly; total time= 2.0min
# [CV] END .....................C=0.5, gamma=1, kernel=sigmoid; total time=   0.1s
# ...

# %%
print("best parameters = ",grid.best_params_)
# Out:
# best parameters =  {'C': 0.5, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
from sklearn.calibration import CalibratedClassifierCV
best_svc = SVC(C=1.0, gamma=0.01, kernel="rbf")
clb_svc = CalibratedClassifierCV( best_svc)
clb_svc.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(base_estimator=SVC(gamma=0.01))

# %%
test_auc3, best_t3 = validate_model(clb_svc, X_train, X_val, y_train, y_val)

print("Best Threshold = {:.4f}".format(best_t3))
print("Model AUC is : {:.4f}".format(test_auc3))
# Out:
# Train AUC =  0.5294556716650698
# Test AUC =  0.46939579057891473
# C:\Users\hp\AppData\Local\Temp\ipykernel_25984\373669981.py:16: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='g', linestyle='-')
# Best Threshold = 0.0809
# Model AUC is : 0.4694

# %%
svc_train_pred = (clb_svc.predict_proba(X_train)[:,1]>0.0547).astype(bool)   # Set threshold to best threshold 
svc_val_pred = (clb_svc.predict_proba(X_val)[:,1]>0.0547).astype(bool)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,cohen_kappa_score,roc_auc_score,f1_score,roc_curve

cm0 = confusion_matrix(y_train, svc_train_pred,labels=[1,0])
print('Confusion Matrix Train : \n', cm0)

cm1 = confusion_matrix(y_val, svc_val_pred,labels=[1,0])
print('Confusion Matrix Test: \n', cm1)

total0=sum(sum(cm0))
total1=sum(sum(cm1))
#####from confusion matrix calculate accuracy
accuracy0=(cm0[0,0]+cm0[1,1])/total0
print ('Accuracy Train : ', accuracy0)

accuracy1=(cm1[0,0]+cm1[1,1])/total1
print ('Accuracy Test : ', accuracy1)

sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )

specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)

KappaValue=cohen_kappa_score(y_val, svc_val_pred)
print("Kappa Value :",KappaValue)
AUC=roc_auc_score(y_val, svc_val_pred)
print("AUC         :",AUC)


print("F1-Score Train",f1_score(y_train,svc_train_pred))
print("F1-Score Validation : ",f1_score(y_val, svc_val_pred))
# Out:
# Confusion Matrix Train :
#  [[ 370    0]
#  [3639    0]]
# Confusion Matrix Test:
#  [[ 92   0]
#  [911   0]]
# Accuracy Train :  0.09229234222998253
# Accuracy Test :  0.09172482552342971
# Sensitivity :  1.0
# Specificity :  0.0
# Kappa Value : 0.0
# AUC         : 0.5
# F1-Score Train 0.1689883535053665
# F1-Score Validation :  0.16803652968036528
